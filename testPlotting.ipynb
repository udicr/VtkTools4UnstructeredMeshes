# %%
# %matplotlib inline
import subprocess
import os
import sys
from tp_utilities import *
from vtk_utilities import *
import matplotlib.pyplot as plt

# %%
solution_3(wd="",sample="sample_4_0/",quiver_filter=1,quiver_scale=0.10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_73127/142441539.py in <module>
# ----> 1 solution_3(wd="",sample="sample_4_0/",quiver_filter=1,quiver_scale=0.10)
#
# /local/buchholz/VtkTools4UnstructeredMeshes/vtk_utilities.py in solution_3(wd, sample, quiver_filter, quiver_scale)
#     372     s.ax2 = s.fig.add_subplot(gs[1])
#     373     s.add_imshow(sample + "U.%04d.vtk" % int((nsol-1)/2), cb=False, ax=s.ax2)
# --> 374     s.add_quivers(sample + "flux.vtk",quiver_filter=quiver_filter, quiver_scale=quiver_scale, ax=s.ax2)
#     375     s.ax2.set_title('t = 0.5')
#     376     s.ax3 = s.fig.add_subplot(gs[2])
#
# /local/buchholz/VtkTools4UnstructeredMeshes/vtk_utilities.py in add_quivers(self, file, quiver_filter, quiver_scale, ax, **kwargs)
#     269             v2[cell_index_y, cell_index_x] = values[cell_value_index][1]
#     270         X, Y = np.meshgrid(x, y)
# --> 271         ax.quiver([X[::quiver_filter, ::quiver_filter], Y[::quiver_filter, ::quiver_filter]],
#     272                        quiver_scale * v1[::quiver_filter, ::quiver_filter],
#     273                        quiver_scale * v2[::quiver_filter, ::quiver_filter], scale=1.0, scale_units='inches', **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in quiver(self, *args, **kwargs)
#    5165         # Make sure units are handled for x and y values
#    5166         args = self._quiver_units(args, kwargs)
# -> 5167         q = mquiver.Quiver(self, *args, **kwargs)
#    5168         self.add_collection(q, autolim=True)
#    5169         self._request_autoscale_view()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/quiver.py in __init__(self, ax, scale, headwidth, headlength, headaxislength, minshaft, minlength, units, scale_units, angles, width, color, pivot, *args, **kwargs)
#     503                          closed=False, **kwargs)
#     504         self.polykw = kwargs
# --> 505         self.set_UVC(U, V, C)
#     506         self._dpi_at_last_init = None
#     507
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/quiver.py in set_UVC(self, U, V, C)
#     553         for name, var in zip(('U', 'V', 'C'), (U, V, C)):
#     554             if not (var is None or var.size == self.N or var.size == 1):
# --> 555                 raise ValueError(f'Argument {name} has a size {var.size}'
#     556                                  f' which does not match {self.N},'
#     557                                  ' the number of arrow positions')
#
# ValueError: Argument U has a size 256 which does not match 289, the number of arrow positions
